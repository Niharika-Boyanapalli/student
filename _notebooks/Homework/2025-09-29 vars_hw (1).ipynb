# %% [markdown]
# ---
# layout: post
# toc: True
# breadcrumb: True
# title: JS Variables Homework
# description: These are the homework problems and popcorn hacks.
# permalink: /csse/javascript/fundamentals/variables-hw
# author: Samarth H, Anish G, Krish K, Pranay K
# ---

# %%
<style>
.glowing-text {
  color: #fff; /* Set the text color to white or a light color for better contrast */
  text-shadow: 0 0 10px #8a2be2, /* Purple glow */
               0 0 20px #8a2be2, /* Deeper purple glow */
               0 0 30px #4169e1, /* Blue glow */
               0 0 40px #4169e1; /* Deeper blue glow */

  font-weight: bold;
  margin-top: 0;
}
</style>

Presented by the
<h4 class="glowing-text">TINKERERS</h4>

<hr>

# <div style="font-weight:bold; text-decoration:underline;">Popcorn Hack 1 🍿😈</div>

Let's start diving into some of the questions. 

## Instructions

Below instructions refer to this code cell:

# %%
# %%html
# <html>
# <body>
#   <h2>Popcorn Hack 1 Output</h2>
#   <div id="output1"></div>
#   <script>
#   (() => {
#     let name = "Niha";
#     let age = 15;
#     let city = "San Diego";
#     let hobby = "painting";
#     // Update DOM and console output
#     let message = `${name} is ${age} years old, lives in ${city}, and loves ${hobby}.`;
#     document.getElementById("output1").innerText = message;
#     console.log(message);
#   })();
#   </script>
# </body>
# </html>

# %% [markdown]
# %%html
# <html>
# <body>
#   <h2>Popcorn Hack 1 Output</h2>
#   <div id="output1"></div>
#   <script>
#   (() => {
#     let name = "Niha";
#     let age = 15;
#     let city = "San Diego";
#     let hobby = "painting";
#     // Update DOM and console output
#     let message = `${name} is ${age} years old, lives in ${city}, and loves ${hobby}.`;
#     document.getElementById("output1").innerText = message;
#     console.log(message);
#   })();
#   </script>
# </body>
# </html>

# %% [markdown]
# Now, do the below with this code.
#
# 1. Adjust var declarations, names, values, etc. Mess around with it and observe any changes/errors.
# 2. Think and/or discuss with your table: what changes did you notice?
#
# Now let's make some changes :)
#
# 3. Uncomment the line saying `age = 2;` and look at your console. What do you notice?
#
# 4. Add a new variable called `hobby` with the value of "painting" and update the DOM output and console output to say:
#    "[NAME] is [AGE] years old, lives in [CITY], and loves [HOBBY]"
#
# 5. There's a keyword called `typeof` in JavaScript. Use this keyword to also display the data types of the variables.
#    Example: `typeof "John"` gives `"string"` and `typeof 3.14` gives `"number"`

# %%
# %%html
# <html>
# <body>
#   <h2>Popcorn Hack 2 Output</h2>
#   <p>Enter your magic number and click Calculate!</p>
#   <input type="number" id="magicInput" placeholder="Enter magic number">
#   <button id="magicButton">Calculate</button>
#   <div id="output2"></div>
#   <script>
#     (() => {
#       const button = document.getElementById("magicButton");
#       const input = document.getElementById("magicInput");
#       const output = document.getElementById("output2");
#       button.addEventListener("click", () => {
#         let magicNumber = input.value;
#         magicNumber = Number(magicNumber);
#         let doubled = magicNumber * 2;
#         let squared = magicNumber ** 2;
#         let tripled = magicNumber * 3;
#         let name = "Niha";
#         let age = 15;
#         let city = "San Diego";
#         let hobby = "Soccer";
#         let message = `${name} is ${age} years old, lives in ${city}, and loves ${hobby}.\nMagic number: ${magicNumber}\nDoubled: ${doubled}, Squared: ${squared}, Tripled: ${tripled}`;
#         output.innerText = message;
#         console.log(message);
#       });
#     })();
#   </script>
# </body>
# </html>
# Out:
# <html>
# <body>
#   <h2>Popcorn Hack 2 Output</h2>
#   <p>Enter your magic number and click Calculate!</p>
#   <input type="number" id="magicInput" placeholder="Enter magic number">
#   <button id="magicButton">Calculate</button>
#   <div id="output2"></div>
#   <script>
#     (() => {
#       const button = document.getElementById("magicButton");
#       const input = document.getElementById("magicInput");
#       const output = document.getElementById("output2");
#       button.addEventListener("click", () => {
#         let magicNumber = input.value;
#         magicNumber = Number(magicNumber);
#         let doubled = magicNumber * 2;
#         let squared = magicNumber ** 2;
#         let tripled = magicNumber * 3;
#         let name = "Niha";
#         let age = 15;
#         let city = "San Diego";
#         let hobby = "Soccer";
# ...

# %%
# %%html
#
# <html>
# <body>
#   <h2>Homework Output</h2>
#   <div id="output"></div>
#
#   <script>
#     document.getElementById("output").innerText = ""; // Clear output
#     (() => {
#
#       // Helper function to print to DOM + console
#       function print(label, msg) {
#         document.getElementById("output").innerText += "\n" + label + ": " + msg;
#         console.log(label + ": " + msg);
#       }
#
#       // Part A - Creating Variables
#
#       // 1. name variable
#       let name = "Niha";
#       print("Part A #1", "My name is " + name);
#
#       // 2. age and city
#       let age = 15;
#       let city = "San Diego";
#       print("Part A #2", "I am " + age + " years old and I live in " + city + ".");
#
#       // 3. isStudent
#       let isStudent = true;
#       print("Part A #3", "Am I a student? " + isStudent);
#
#       // Part B – Numbers & Strings
#
#       // 4. Numbers
#       let num1 = 10;
#       let num2 = 5;
#       print("Part B #4a", "Sum = " + (num1 + num2));
#       print("Part B #4b", "Difference = " + (num1 - num2));
#       print("Part B #4c", "Product = " + (num1 * num2));
#       print("Part B #4d", "Quotient = " + (num1 / num2));
#
#       // 5. favoriteFood
#       let favoriteFood = "Pizza";
#       print("Part B #5", "My favorite food is " + favoriteFood + ".");
#
#       // Part C – Practice Problems
#
#       // 6. Swap x and y
#       let x = 7;
#       let y = 3;
#       print("Part C #6 (before)", "x=" + x + ", y=" + y);
#       let temp = x;
#       x = y;
#       y = temp;
#       print("Part C #6 (after)", "x=" + x + ", y=" + y);
#
#       // 7. fullName
#       let firstName = "Niharika";
#       let lastName = "Boyanapalli";
#       let fullName = firstName + " " + lastName;
#       print("Part C #7", "Full name = " + fullName);
#
#       // 8. Celsius to Fahrenheit
#       let C = 25;
#       let F = (C * 9/5) + 32;
#       print("Part C #8", C + "°C = " + F + "°F");
#
#       // 9. Pass/Fail
#       let score = 85;
#       if (score >= 50) {
#         print("Part C #9", "Pass (Score = " + score + ")");
#       } else {
#         print("Part C #9", "Fail (Score = " + score + ")");
#       }
#
#       // Extra Credit: random score 1–100
#       let randomScore = Math.floor(Math.random() * 100) + 1;
#       if (randomScore >= 50) {
#         print("Extra Credit", "Random Score = " + randomScore + " → Pass");
#       } else {
#         print("Extra Credit", "Random Score = " + randomScore + " → Fail");
#       }
#
#       // 10. Ask for name and age
# let userName = prompt("Enter your name:", "Niha");
# let userAge = prompt("Enter your age:", "15");
#
# // If the user presses Cancel or leaves it blank, use default values
# if (!userName) userName = "Niha";
# if (!userAge) userAge = "15";
#
# // Display in DOM and console
# print("Part C #10", "Hello " + userName + ", you are " + userAge + " years old.");
#
#
#       // 11. Mini-project (Shopping cart example)
#       let item1 = "Book";
#       let item2 = "Pen";
#       let price1 = 12.99;
#       let price2 = 1.50;
#       let total = price1 + price2;
#       print("Part C #11", "You bought a " + item1 + " and a " + item2 + ". Total = $" + total.toFixed(2));
#
#     })();
#   </script>
# </body>
# </html>
# Out:
# <html>
# <body>
#   <h2>Homework Output</h2>
#   <div id="output"></div>
#
#   <script>
#     document.getElementById("output").innerText = ""; // Clear output
#     (() => {
#
#       // Helper function to print to DOM + console
#       function print(label, msg) {
#         document.getElementById("output").innerText += "\n" + label + ": " + msg;
#         console.log(label + ": " + msg);
#       }
#
#       // Part A - Creating Variables
#
#       // 1. name variable
#       let name = "Niha";
#       print("Part A #1", "My name is " + name);
#
#       // 2. age and city
#       let age = 15;
#       let city = "San Diego";
#       print("Part A #2", "I am " + age + " years old and I live in " + city + ".");
#
#       // 3. isStudent
#       let isStudent = true;
#       print("Part A #3", "Am I a student? " + isStudent);
#
#       // Part B – Numbers & Strings
#
#       // 4. Numbers
#       let num1 = 10;
#       let num2 = 5;
# ...
